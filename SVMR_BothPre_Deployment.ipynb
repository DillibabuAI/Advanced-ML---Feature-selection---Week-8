# %%
# Model Loading and Prediction
import pickle
loaded_model = pickle.load(open("finalized_model_svr.sav", 'rb'))

# %%
loaded_sc = pickle.load(open("finalized_sc_input.sav", 'rb'))
preinput = loaded_sc.transform([[1300, 12000, 4000, 0, 1]])
preinput
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([[-1.46755405, -4.33835385, -1.50744257, -0.5       ,  1.30088727]])

# %%
loaded_model = pickle.load(open("finalized_model_svr.sav", 'rb'))
result = loaded_model.predict(preinput)
result
# Out:
# array([-1.03109284])

# %%
loaded_scy = pickle.load(open("finalized_scy_output.sav", 'rb'))
output = loaded_scy.inverse_transform([result])
output
# Out:
# array([[65875.16964031]])
